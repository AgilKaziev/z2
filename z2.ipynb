# %%
print ("                             Ministerstvo образования и науки РФ")
print ("\n              Санкт-Петербургский polytechnichesky университет Петра Великого")
print ("\n                         Институт компьютерных наук и технологий")
print ("\n                   Высшая школа *«Киберфизических систем и управления»*")
print ("\nУДК__________")
print ("\n                                                                                       УТВЕРЖДАЮ")
print ("\n                                                                           _____________________")
print ("\n                                                                           _____________________")
print ("\n                                                                           _____________________")
print ("\n                                                                           '___'__________ ____г")
print ("\n")
print ("\n")
print ("\n")
print ("\n                                          Реферат")
print ("\n                     по дисциплине «Практикум по программированию»")
print ("\n")
print ("\n")
print ("\n")
print ("\n")
print ("\nВыполнил:")
print ("\nстудент гр. з3530902/90001                                        _________________А.В. Казиев")
print ("\n                                                                  подпись, дата")
print ("\n")
print ("\n")
print ("\nПроверил:")
print ("\nдоцент к.ф.-м.н.                                               _________________ А.А. Жиленков")
print ("\n                                                               подпись, дата")
print ("\n")
print ("\n")
print ("\n")
print ("\n")
print ("\n                                  Санкт-Петербург 2021 г.")
# Out:
#                              Ministerstvo образования и науки РФ
#
#               Санкт-Петербургский polytechnichesky университет Петра Великого
#
#                          Институт компьютерных наук и технологий
#
#                    Высшая школа *«Киберфизических систем и управления»*
#
# УДК__________
#
#                                                                                        УТВЕРЖДАЮ
#
#                                                                            _____________________
#
#                                                                            _____________________
#
#                                                                            _____________________
#
#                                                                            '___'__________ ____г
#
#
#
#
#
#
#
#                                           Реферат
#
#                      по дисциплине «Практикум по программированию»
#
#
#
#
#
#
#
#
#
# Выполнил:
#
# студент гр. з3530902/90001                                        _________________А.В. Казиев
#
#                                                                   подпись, дата
#
#
#
#
#
# Проверил:
#
# доцент к.ф.-м.н.                                               _________________ А.А. Жиленков
#
#                                                                подпись, дата
#
#
#
#
#
#
#
#
#
#                                   Санкт-Петербург 2021 г.
